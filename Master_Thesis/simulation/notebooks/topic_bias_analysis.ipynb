# %%
import json
import pandas as pd
import ast
import seaborn as sns
import matplotlib.pyplot as plt

# %%
topic_bias_df=pd.read_csv("../data/all_fits_combined.csv")
topic_bias_df.columns
# Out:
# Index(['Model', 'Size', 'Opinion_A', 'Opinion_B', 'beta', 'h', 'delta_P',
#        'MSE', 'R_squared', 'Filepath'],
#       dtype='str')

# %%
topic_bias_qwen_df=topic_bias_df[topic_bias_df["Model"].str.contains('qwen', case=False, na=False)]
topic_bias_qwen_df.sort_values(by=['Model','h'])
# Out:
#                     Model  Size                          Opinion_A  \
# 179  Qwen2.5-14B-Instruct    50         mandatory military service
# 133  Qwen2.5-14B-Instruct    50                     big government
# 114  Qwen2.5-14B-Instruct    50  money as speech (Citizens United)
# 165  Qwen2.5-14B-Instruct    50             pornography acceptable
# 96   Qwen2.5-14B-Instruct    50                     Israel support
# ..                    ...   ...                                ...
# 438             Qwen3-32B    50             rehabilitative justice
# 419             Qwen3-32B    50                             summer
# 498             Qwen3-32B    50          property rights above all
# 490             Qwen3-32B    50            climate change believer
# 467             Qwen3-32B    50                           feminist
#
#                              Opinion_B      beta          h   delta_P  \
# 179         voluntary military service  3.269993  -0.361915  0.000100
# ...
